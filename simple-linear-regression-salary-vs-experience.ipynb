# %% [markdown]
# <a href="https://www.kaggle.com/code/sandhyakrishnan02/simple-linear-regression-salary-vs-experience?scriptVersionId=100694071" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Importing Libraries and Dataset

# %% [markdown]
# Regression analysis is the most widely used method of prediction. Linear regression is used when the dataset has a linear correlation and as the name suggests, simple linear regression has one independent variable (predictor) and one dependent variable(response).
#
# The simple linear regression equation is represented as y = a+bx where x is the explanatory variable, y is the dependent variable, b is coefficient and a is the intercept.
#
# For regression analysis, first we have to import libraries.

# %%
#Importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import plotly.express as px
import plotly.graph_objs as go
from plotly.offline import iplot

# %% [markdown]
# After importing libraries, the dataset is to be imported.

# %%
#Importing dataset
dataset = pd.read_csv('../input/salary-data-simple-linear-regression/Salary_Data.csv')

# %% [markdown]
# To see the first five rows of the dataset we can use dataset.head().

# %% [markdown]
# # Data Analysis

# %%
#To see first 5 rows of the dataset
dataset.head().style.background_gradient(cmap='pink_r')
# Out:
# <style  type="text/css" >
# #T_6d2e7_row0_col0,#T_6d2e7_row2_col1{
#             background-color:  #ffffff;
#             color:  #000000;
#         }#T_6d2e7_row0_col1{
#             background-color:  #eeeeca;
#             color:  #000000;
#         }#T_6d2e7_row1_col0{
#             background-color:  #efefcc;
#             color:  #000000;
#         }#T_6d2e7_row1_col1,#T_6d2e7_row4_col0{
#             background-color:  #1e0000;
#             color:  #f1f1f1;
#         }#T_6d2e7_row2_col0{
#             background-color:  #decfa6;
#             color:  #000000;
#         }#T_6d2e7_row3_col0{
#             background-color:  #8a5858;
#             color:  #f1f1f1;
#         }#T_6d2e7_row3_col1{
#             background-color:  #b47575;
#             color:  #000000;
#         }#T_6d2e7_row4_col1{
#             background-color:  #e8e8b4;
#             color:  #000000;
#         }</style><table id="T_6d2e7_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >YearsExperience</th>        <th class="col_heading level0 col1" >Salary</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6d2e7_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6d2e7_row0_col0" class="data row0 col0" >1.100000</td>
#                         <td id="T_6d2e7_row0_col1" class="data row0 col1" >39343.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_6d2e7_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6d2e7_row1_col0" class="data row1 col0" >1.300000</td>
#                         <td id="T_6d2e7_row1_col1" class="data row1 col1" >46205.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_6d2e7_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_6d2e7_row2_col0" class="data row2 col0" >1.500000</td>
#                         <td id="T_6d2e7_row2_col1" class="data row2 col1" >37731.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_6d2e7_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_6d2e7_row3_col0" class="data row3 col0" >2.000000</td>
#                         <td id="T_6d2e7_row3_col1" class="data row3 col1" >43525.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_6d2e7_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_6d2e7_row4_col0" class="data row4 col0" >2.200000</td>
#                         <td id="T_6d2e7_row4_col1" class="data row4 col1" >39891.000000</td>
#             </tr>
#     </tbody></table>

# %%
# To see information of dataset
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %% [markdown]
# Both are numerical column

# %%
dataset.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# There is no null value in dataset

# %% [markdown]
# Statistical analysis of the dataset like no: of observation, mean, standard deviation and interquartile value can be done using the dataset. describe().

# %%
#Statistical Analysis
dataset.describe().style.background_gradient(cmap='pink_r')
# Out:
# <style  type="text/css" >
# #T_41c72_row0_col0,#T_41c72_row7_col1{
#             background-color:  #1e0000;
#             color:  #f1f1f1;
#         }#T_41c72_row0_col1,#T_41c72_row3_col0{
#             background-color:  #ffffff;
#             color:  #000000;
#         }#T_41c72_row1_col0{
#             background-color:  #f2f2d7;
#             color:  #000000;
#         }#T_41c72_row1_col1{
#             background-color:  #c38480;
#             color:  #000000;
#         }#T_41c72_row2_col0{
#             background-color:  #fafaf0;
#             color:  #000000;
#         }#T_41c72_row2_col1{
#             background-color:  #ebebbe;
#             color:  #000000;
#         }#T_41c72_row3_col1{
#             background-color:  #e4ddad;
#             color:  #000000;
#         }#T_41c72_row4_col0{
#             background-color:  #f9f9ed;
#             color:  #000000;
#         }#T_41c72_row4_col1{
#             background-color:  #d4b699;
#             color:  #000000;
#         }#T_41c72_row5_col0{
#             background-color:  #f4f4de;
#             color:  #000000;
#         }#T_41c72_row5_col1{
#             background-color:  #cda18e;
#             color:  #000000;
#         }#T_41c72_row6_col0{
#             background-color:  #ebebbd;
#             color:  #000000;
#         }#T_41c72_row6_col1{
#             background-color:  #885757;
#             color:  #f1f1f1;
#         }#T_41c72_row7_col0{
#             background-color:  #e2d8ab;
#             color:  #000000;
#         }</style><table id="T_41c72_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >YearsExperience</th>        <th class="col_heading level0 col1" >Salary</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_41c72_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_41c72_row0_col0" class="data row0 col0" >30.000000</td>
#                         <td id="T_41c72_row0_col1" class="data row0 col1" >30.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_41c72_level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_41c72_row1_col0" class="data row1 col0" >5.313333</td>
#                         <td id="T_41c72_row1_col1" class="data row1 col1" >76003.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_41c72_level0_row2" class="row_heading level0 row2" >std</th>
#                         <td id="T_41c72_row2_col0" class="data row2 col0" >2.837888</td>
#                         <td id="T_41c72_row2_col1" class="data row2 col1" >27414.429785</td>
#             </tr>
#             <tr>
#                         <th id="T_41c72_level0_row3" class="row_heading level0 row3" >min</th>
#                         <td id="T_41c72_row3_col0" class="data row3 col0" >1.100000</td>
#                         <td id="T_41c72_row3_col1" class="data row3 col1" >37731.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_41c72_level0_row4" class="row_heading level0 row4" >25%</th>
#                         <td id="T_41c72_row4_col0" class="data row4 col0" >3.200000</td>
#                         <td id="T_41c72_row4_col1" class="data row4 col1" >56720.750000</td>
#             </tr>
#             <tr>
#                         <th id="T_41c72_level0_row5" class="row_heading level0 row5" >50%</th>
#                         <td id="T_41c72_row5_col0" class="data row5 col0" >4.700000</td>
#                         <td id="T_41c72_row5_col1" class="data row5 col1" >65237.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_41c72_level0_row6" class="row_heading level0 row6" >75%</th>
#                         <td id="T_41c72_row6_col0" class="data row6 col0" >7.700000</td>
#                         <td id="T_41c72_row6_col1" class="data row6 col1" >100544.750000</td>
#             </tr>
#             <tr>
#                         <th id="T_41c72_level0_row7" class="row_heading level0 row7" >max</th>
#                         <td id="T_41c72_row7_col0" class="data row7 col0" >10.500000</td>
#                         <td id="T_41c72_row7_col1" class="data row7 col1" >122391.000000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# The relationship between variables can be seen by using sns.pairplot(). For multiple linear regression, it will be very useful, as it shows each feature's relationship with the response.

# %% [markdown]
# # Heat Map

# %%
fig = px.imshow(dataset.corr())
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="513156cb-a134-4626-a39d-9b99f51d6cb1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("513156cb-a134-4626-a39d-9b99f51d6cb1")) {                    Plotly.newPlot(                        "513156cb-a134-4626-a39d-9b99f51d6cb1",                        [{"coloraxis": "coloraxis", "hovertemplate": "x: %{x}<br>y: %{y}<br>color: %{z}<extra></extra>", "name": "0", "type": "heatmap", "x": ["YearsExperience", "Salary"], "xaxis": "x", "y": ["YearsExperience", "Salary"], "yaxis": "y", "z": [[1.0, 0.97824161848876], [0.97824161848876, 1.0]]}],                        {"coloraxis": {"colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], ...

# %% [markdown]
# # Visualization

# %% [markdown]
# ## Scatter Plot

# %%
scatter = [go.Scatter(x = dataset['YearsExperience'],
                      y = dataset['Salary'],
                      mode ='markers')] 

fig = go.Figure(scatter)

iplot(fig)
# Out:
# <div>                            <div id="0bddbede-3574-4f98-8d9b-d4296fd2e2e6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0bddbede-3574-4f98-8d9b-d4296fd2e2e6")) {                    Plotly.newPlot(                        "0bddbede-3574-4f98-8d9b-d4296fd2e2e6",                        [{"mode": "markers", "type": "scatter", "x": [1.1, 1.3, 1.5, 2.0, 2.2, 2.9, 3.0, 3.2, 3.2, 3.7, 3.9, 4.0, 4.0, 4.1, 4.5, 4.9, 5.1, 5.3, 5.9, 6.0, 6.8, 7.1, 7.9, 8.2, 8.7, 9.0, 9.5, 9.6, 10.3, 10.5], "y": [39343.0, 46205.0, 37731.0, 43525.0, 39891.0, 56642.0, 60150.0, 54445.0, 64445.0, 57189.0, 63218.0, 55794.0, 56957.0, 57081.0, 61111.0, 67938.0, 66029.0, 83088.0, 81363.0, 93940.0, 91738.0, 98273.0, 101302.0, 113812.0, 109431.0, 105582.0, 116969.0, 112635.0, 122391.0, 121872.0]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": { ...

# %% [markdown]
# ## histogram

# %%
hist = [go.Histogram(x = dataset['YearsExperience'],\
                     marker=dict(color ='#AFE400',line = dict(color='black',width=2)))]


fig = go.Figure(data = hist)

iplot(fig)
# Out:
# <div>                            <div id="10925357-efda-4d40-92c7-74eae7bcf519" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("10925357-efda-4d40-92c7-74eae7bcf519")) {                    Plotly.newPlot(                        "10925357-efda-4d40-92c7-74eae7bcf519",                        [{"marker": {"color": "#AFE400", "line": {"color": "black", "width": 2}}, "type": "histogram", "x": [1.1, 1.3, 1.5, 2.0, 2.2, 2.9, 3.0, 3.2, 3.2, 3.7, 3.9, 4.0, 4.0, 4.1, 4.5, 4.9, 5.1, 5.3, 5.9, 6.0, 6.8, 7.1, 7.9, 8.2, 8.7, 9.0, 9.5, 9.6, 10.3, 10.5]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": ...

# %%
hist = [go.Histogram(x = dataset['Salary'],\
                     marker=dict(color ='#0FE400',line = dict(color='black',width=2)))]

fig = go.Figure(data = hist)

iplot(fig)
# Out:
# <div>                            <div id="b689893a-a458-4780-83d4-95cd1b892cfe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b689893a-a458-4780-83d4-95cd1b892cfe")) {                    Plotly.newPlot(                        "b689893a-a458-4780-83d4-95cd1b892cfe",                        [{"marker": {"color": "#0FE400", "line": {"color": "black", "width": 2}}, "type": "histogram", "x": [39343.0, 46205.0, 37731.0, 43525.0, 39891.0, 56642.0, 60150.0, 54445.0, 64445.0, 57189.0, 63218.0, 55794.0, 56957.0, 57081.0, 61111.0, 67938.0, 66029.0, 83088.0, 81363.0, 93940.0, 91738.0, 98273.0, 101302.0, 113812.0, 109431.0, 105582.0, 116969.0, 112635.0, 122391.0, 121872.0]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type ...

# %% [markdown]
# # Assigning dependent variable to y and independent variable to X.

# %%
#Assiging values in X & Y
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
print(X)
# Out:
# [[ 1.1]
#  [ 1.3]
#  [ 1.5]
#  [ 2. ]
#  [ 2.2]
#  [ 2.9]
#  [ 3. ]
#  [ 3.2]
#  [ 3.2]
#  [ 3.7]
#  [ 3.9]
#  [ 4. ]
#  [ 4. ]
#  [ 4.1]
#  [ 4.5]
#  [ 4.9]
#  [ 5.1]
#  [ 5.3]
#  [ 5.9]
#  [ 6. ]
#  [ 6.8]
#  [ 7.1]
#  [ 7.9]
#  [ 8.2]
#  [ 8.7]
#  [ 9. ]
#  [ 9.5]
#  [ 9.6]
#  [10.3]
#  [10.5]]

# %%
print(y)
# Out:
# [ 39343.  46205.  37731.  43525.  39891.  56642.  60150.  54445.  64445.
#   57189.  63218.  55794.  56957.  57081.  61111.  67938.  66029.  83088.
#   81363.  93940.  91738.  98273. 101302. 113812. 109431. 105582. 116969.
#  112635. 122391. 121872.]

# %% [markdown]
# The dataset has to be split into a training set and a test set analysis. This can be done by the function train_test_split function from the Model_selection module of the Scikit-learn library.

# %% [markdown]
# # Spliting Dataset

# %%
#Splitting testdata into X_train,X_test,y_train,y_test
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.33,random_state=42)

# %% [markdown]
# Now the data set will be divided into X_train,X_test,y_train,y_test based on the test_size we have provided as input.
#
# Here dataset has 30 observations and test_size is taken as 33% of the total observation. This indicates the test set should have 33% * 30 =9.9 ~10 observations and the training set should have 20 observations. Random_state is assigned to some value so that the dataset is split randomly.

# %%
print(X_train)
# Out:
# [[ 2.2]
#  [ 5.1]
#  [ 2.9]
#  [ 4.1]
#  [ 4. ]
#  [ 7.9]
#  [ 1.3]
#  [ 1.5]
#  [ 9. ]
#  [ 2. ]
#  [ 7.1]
#  [ 9.5]
#  [ 5.9]
#  [10.5]
#  [ 6.8]
#  [ 3.2]
#  [ 3.9]
#  [ 4.5]
#  [ 6. ]
#  [ 3. ]]

# %%
print(X_test)
# Out:
# [[ 9.6]
#  [ 4.9]
#  [ 8.2]
#  [ 5.3]
#  [ 3.2]
#  [ 3.7]
#  [10.3]
#  [ 8.7]
#  [ 4. ]
#  [ 1.1]]

# %%
print(y_train)
# Out:
# [ 39891.  66029.  56642.  57081.  55794. 101302.  46205.  37731. 105582.
#   43525.  98273. 116969.  81363. 121872.  91738.  54445.  63218.  61111.
#   93940.  60150.]

# %%
print (y_test)
# Out:
# [112635.  67938. 113812.  83088.  64445.  57189. 122391. 109431.  56957.
#   39343.]

# %% [markdown]
# random_state is provided as input to divide the test set and the training set randomly. If we use random_state as 47, then the dataset will be divided in a different random way.

# %% [markdown]
# # Linear Regression

# %% [markdown]
# To perform linear regression, LinearRegression class is imported from the module linear_model of the Scikit-learn library. The simple regression model built will be an instance of class LinearRegression.

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [raw]
# There is no need to assign lr.fit(X_train, y_train) to a variable as the fitting is done on the instance itself. Also here we will be only fitting the training set because the test set we will be used to validate the model.
# Our test set has 10 observations and for each observation, we have to predict the salary. So the input for predict method will be the year of experience of the test set and we have to compare the predicted salary with its real salary.

# %% [markdown]
# # Predict

# %%
#Prediciting Y from Linear regression Model
y_pred = lr.predict(X_test)

# %% [markdown]
# Traning data is visualized with X_train and y_train, the red mark indicates the data point and the blue line indicates the regression line or best fit line.

# %% [markdown]
# # ScatterPlot

# %%
x_range = np.linspace(X.min(), X.max(), 100)
y_range = lr.predict(x_range.reshape(-1, 1))

fig = go.Figure([
        go.Scatter(x=X_train.squeeze(), y=y_train, 
                   name='train', mode='markers'),
        go.Scatter(x=X_test.squeeze(), y=y_test, 
                   name='test', mode='markers'),
        go.Scatter(x=x_range, y=y_range, 
                   name='prediction')
    ])

fig.show()
# Out:
# <div>                            <div id="1d45a4b1-6dfa-4afc-861b-4ca2f669b766" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1d45a4b1-6dfa-4afc-861b-4ca2f669b766")) {                    Plotly.newPlot(                        "1d45a4b1-6dfa-4afc-861b-4ca2f669b766",                        [{"mode": "markers", "name": "train", "type": "scatter", "x": [2.2, 5.1, 2.9, 4.1, 4.0, 7.9, 1.3, 1.5, 9.0, 2.0, 7.1, 9.5, 5.9, 10.5, 6.8, 3.2, 3.9, 4.5, 6.0, 3.0], "y": [39891.0, 66029.0, 56642.0, 57081.0, 55794.0, 101302.0, 46205.0, 37731.0, 105582.0, 43525.0, 98273.0, 116969.0, 81363.0, 121872.0, 91738.0, 54445.0, 63218.0, 61111.0, 93940.0, 60150.0]}, {"mode": "markers", "name": "test", "type": "scatter", "x": [9.6, 4.9, 8.2, 5.3, 3.2, 3.7, 10.3, 8.7, 4.0, 1.1], "y": [112635.0, 67938.0, 113812.0, 83088.0, 64445.0, 57189.0, 122391.0, 109431.0, 56957.0, 39343.0]}, {"name": "prediction", "type": "scatter", "x": [1.1, 1.194949494949495, 1.2898989898989899, 1.384848484848485, 1.47979797979798, 1.5747474747474748, 1.66969696969697, 1.7646464646464648, 1.8595959595959597, 1.9545454545454546, 2.0494949494949495, 2.144444444444445, 2.2393939393939393, 2.3343434343434346, 2.4292929292929295, 2.5242424242424244, 2.6191919191919193, 2.714141414141414, 2.809090909090909, 2.904040404040404, 2.9989898989898993, 3.0939393939393938, 3.188888888888889, 3.283838383838384, 3.378787878787879, 3.473737373737374, 3.5686868686868687, 3.6636363636363636, 3.758585858585859, 3.853535353535354, 3.9484848484848487, 4.043434343434344, 4.138383838383838, 4.233333333333333, 4.328282828282829, 4.423232323232323, 4.518181818181818, 4.613131313131314, 4.708080808080808, 4.803030303030303, 4.897979797979798, 4.992929292929293, 5.087878787878788, 5.182828282828282, 5.277777777777779, 5.372727272727273, 5.4676767676767675, 5.562626262626262, 5.657575757575758, 5.752525252525253, 5.847474747474747, 5.942424242424243, 6.037373737373738, 6.132323232323232, 6.227272727272727, 6.322222222222223, 6.417171717171717, 6.512121212121212, 6.607070707070708, 6.702020202020202, 6.796969696969697, 6.891919191919191, 6.986868686868688, 7.081818181818182, 7.1767676767676765, 7.271717171717173, 7.366666666666667, 7.461616161616162, 7.556565656565656, 7.651515151515152, 7.746464646464647, 7.841414141414141, 7.936363636363636, 8.031313131313132, 8.126262626262626, 8.22121212121212, 8.316161616161617, 8.411111111111111, 8.506060606060606, 8.6010101010101, 8.695959595959597, 8.790909090909091, 8.885858585858585, 8.980808080808082, 9.075757575757576, 9.17070707070707, 9.265656565656565, 9.36060606060606, 9.455555555555556, 9.55050505050505, 9.645454545454545, 9.74040404040404, 9.835353535353535, 9.93030303030303, 10.025252525252524, 10.12020202020202, 10.215151515151515, 10.31010101010101, 10.405050505050506, 10.5], "y": [35692.97802522665, 36587.97564572466, 37482.973266222674, 38377.970886720694, 39272.968507218706, 40167.96612771672, 41062.96374821474, 41957.96136871275, 42852.95898921076, 43747.95660970878, 44642.95423020679, 45537.95185070481, 46432.949471202824, 47327.947091700844, 48222.94471219885, 49117.94233269687, 50012.93995319488, 50907.93757369289, 51802.93519419091, 52697.932814688924, 53592.93043518694, 54487.928055684955, 55382.925676182975, 56277.92329668098, 57172.920917179, 58067.91853767701, 58962.91615817502, 59857.91377867304, 60752.911399171055, 61647.909019669074, 62542.906640167086, 63437.9042606651, 64332.90188116311, 65227.89950166113, 66122.89712215915, 67017.89474265715, 67912.89236315517, 68807.8899836532, 69702.88760415121, 70597.88522464922, 71492.88284514722, 72387.88046564526, 73282.87808614326, 74177.87570664127, 75072.8733271393, 75967.8709476373, 76862.86856813531, 77757.86618863331, 78652.86380913135, 79547.86142962935, 8044 ...

# %% [markdown]
# # Coefficient and Intercept

# %% [markdown]
# To find the linear regression equation, coefficient and intercept are to be calculated which can be done with the below equation.

# %%
#Assigning Coefficient (slope) to b
b = lr.coef_

# %%
print("Coefficient  :" , b)
# Out:
# Coefficient  : [9426.03876907]

# %%
#Assigning Y-intercept to a
a = lr.intercept_

# %%
print("Intercept : ", a)
# Out:
# Intercept :  25324.33537924433

# %% [markdown]
# # Predicting Unknown Values

# %% [markdown]
# For this model, the linear regression equation will be:
#
# Predicted Salary=9426.03876907×(years of experience)+25324.33537924433
#
# For Years of Experience 11, predicted salary can be calculated as:
#
# 9426.03876907×(11)+25324.33537924433 = 129010.76183907
#
# y(11) can be predicted with the model as below.

# %%
# y_pred=9426.03876907×(years of experience)+25324.33537924433
#y_predict(11)
print(lr.predict([[11]]))
# Out:
# [129010.76183907]

# %% [markdown]
# Mean Squared Error (MSE) is one of the regression evaluation metrics. It is calculated as the average squared difference between the predicted values and the real value. The mathematical equation for MSE is as:
# ![image.png](attachment:image.png)

# %% [markdown]
# MSE can be calculated from the metrics module of Scikit-learn library.

# %% [markdown]
# # Evaluation

# %%
#Mean Squared Error (MSE)
from sklearn import metrics

# %%
print('Mean Squared Error (MSE)  : ', metrics.mean_squared_error(y_test, y_pred))
# Out:
# Mean Squared Error (MSE)  :  35301898.887134895

# %%
import statsmodels.api as sm

# %% [markdown]
# Ordinary Least-Squares (OLS) estimator module can be called from statsmodels.api to get regression summary.

# %%
X_stat = sm.add_constant(X_train)
regsummary = sm.OLS(y_train, X_stat).fit()
regsummary.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.955
# Model:                            OLS   Adj. R-squared:                  0.952
# Method:                 Least Squares   F-statistic:                     381.3
# Date:                Wed, 13 Jul 2022   Prob (F-statistic):           1.45e-13
# Time:                        06:13:30   Log-Likelihood:                -200.48
# No. Observations:                  20   AIC:                             405.0
# Df Residuals:                      18   BIC:                             406.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.532e+04   2743.538      9.231      0.000    1.96e+04    3.11e+04
# x1          9426.0388    482.706     19.527      0.000    8411.911    1.04e+04
# ==============================================================================
# Omnibus:                        0.822   Durbin-Watson:                   1.772
# Prob(Omnibus):                  0.663   Jarque-Bera (JB):                0.819
# Skew:                           0.380   Prob(JB):                        0.664
# Kurtosis:                       2.363   Cond. No.                         12.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# R-Square or Adj-R-Square value can be obtained as below.

# %%
print("Adjusted R-Square : ",regsummary.rsquared_adj)
print("R-Square : ",regsummary.rsquared)
# Out:
# Adjusted R-Square :  0.9524194554302405
# R-Square :  0.9549236946181227

# %% [markdown]
# If only interested to find the R-Square value, r2_score can be imported from the metrics module of the Scikit-learn library.

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_train, lr.predict(X_train))
# Out:
# 0.9549236946181227

# %% [markdown]
# # Reference
#
# https://medium.com/geekculture/simple-linear-regression-analysis-using-python-c5b2f637942
